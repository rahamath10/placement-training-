# %% [markdown]
# <a href="https://colab.research.google.com/github/rahamath10/placement-training-/blob/main/19_01_26training_session.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if (12 and 24):
  print("Hello")
else:
  print("Hi")
# Out:
# Hello

# %%
a= int(input("Enter  a value for A:"))
b=int(input("Enter a value for B:"))
c= a+b
print("Addition of two number is :", c)

if (c==a):
  print("right")
else:
  print("wrong")
# Out:
# Enter  a value for A:6
# Enter a value for B:0
# Addition of two number is : 6
# right

# %%
a= int(input("Enter  a value for A:"))
b=int(input("Enter a value for B:"))
c= a+b
print("Addition of two number is :", c)

if (c==a):
  print("right")
else:
  print("wrong")
# Out:
# Enter  a value for A:3
# Enter a value for B:6
# Addition of two number is : 9
# wrong
